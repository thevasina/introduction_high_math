# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab
import math
import decimal
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ##                                                     Задания к уроку 2

# %% [markdown]
#    ### 1. Задание
#  Даны два вектора в трехмерном пространстве: (10,10,10) и (0,0,-10)
# - **Найдите их сумму. (на листочке)**

# %% [markdown]
#     X: = (10,10,10)
#     Y: = (0,0,-10)
#
# X_Y_sum: = (10,10,10) + (0,0,-10) = (10,10,0)

# %% [markdown]
# - **Напишите код на Python, реализующий расчет длины вектора, заданного его координатами. (в программе)**

# %%
x = (10,10,10)
y = (0,0,-10)

# %%
sum = 0
for i in x:
    sum += i**2
length = math.sqrt(sum)
print(length)
# Out:
# 17.320508075688775

# %%
sum = 0
for i in y:
    sum += i**2
length = math.sqrt(sum)
print(length)
# Out:
# 10.0

# %% [markdown]
# ### 2. Задание (на листочке)
# - Почему прямые не кажутся перпендикулярными? (см.ролик)

# %% [markdown]
# При ближайшем рассмотрении видим, что масштаб графика - не точный. Ячейки не квадратные, соответственно угол наклона прямых искажен и угол не прямой.

# %%
x = np.linspace(-15, 15, 100)
y = np.arange(-20, 20)
ax1 = plt.gca()
ax1.axhline(y=0, color='k')
ax1.axvline(x=0, color='k')
ax1.grid()
x1 = np.arange(-20, 20)
y1 = 3*x + 1
y2 = -(1/3)*x +1
plt.plot(x,y1)
plt.plot(x, y2)
pylab.xlim (-10, 10)
pylab.ylim (-10, 10)
plt.show()

# %% [markdown]
# ###  3. Задание (в программе)
# Напишите код на Python, реализующий построение графиков:
# - **окружности**

# %%
ax1 = plt.gca()
ax1.axhline(y=0, color='k')
ax1.axvline(x=0, color='k')
ax1.grid()

a = np.linspace(0, 2 * np.pi, 100)
r = 5
x = r * np.cos(a)
y = r * np.sin(a) + 2
ax1.plot(x, y)

pylab.xlim (-10, 10)
pylab.ylim (-10, 10)
plt.show()

# %% [markdown]
# - **эллипса**

# %%
x = []
x2 = []
y = []
y2 = []

for i in range(1000):
    a = 40
    b = 20
    x.append(-i)
    x2.append(i)
    y.append(np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))
    y2.append(-np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))
       
plt.plot(x, y, color='r')
plt.plot(x, y2, color='r')
plt.plot(x2, y2, color='r')
plt.plot(x2, y, color='r')
plt.axis('scaled')
plt.show()
# Out:
# <ipython-input-9-63d91782bc33>:11: RuntimeWarning: invalid value encountered in sqrt
#   y.append(np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))
# <ipython-input-9-63d91782bc33>:12: RuntimeWarning: invalid value encountered in sqrt
#   y2.append(-np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))

# %% [markdown]
# - **гиперболы**

# %%
ax1 = plt.gca()
ax1.axhline(y=0, color='k')
ax1.axvline(x=0, color='k')
ax1.grid()
xmin = -20
xmax = 20
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4)

ylist = 1 / xlist

plt.plot(xlist, ylist)
plt.show()
# Out:
# <ipython-input-11-cadad4bf1f9d>:11: RuntimeWarning: divide by zero encountered in true_divide
#   ylist = 1 / xlist

# %% [markdown]
# ### 4. Задание (на листочке)
#     1) Пусть задана плоскость:
#
# Ax + By + Cz + D = 0
#
# - Напишите уравнение плоскости, параллельной данной и проходящей через начало координат.
#
#     Чтобы плоскость проходила через начало координат (0,0,0), нужно, чтобы выполнялось A*0+B*0+C*0+D=0, т. е. надо взять D=0.
#
#     Ax + By + Cz = 0

# %% [markdown]
#     2)  Пусть задана плоскость: A1x + B1y + C1z + D1 = 0
#     и прямая:
#     x-x1/x2-x1 = y-y1/y2-y1 = z-z1/z2-z1
#
#     Как узнать, принадлежит прямая плоскости или нет?
#
# Имея уравнение прямой мы знаем координаты 2-х  точек A(x, y, z) & A1(x1,y1,z1), принадлежащих этой прямой, возьмем координаты этих точек и подставим  в уравнение плоскости. Если при решении уравнения не выполняется равенство значит прямая  не принадлежит этой плоскости.

# %% [markdown]
# ### 5. Задание (в программе)
# 1. Нарисуйте трехмерный график двух параллельных плоскостей.

# %%
fig = plt.figure(figsize = (8, 8))
ax = Axes3D(fig)
X = np.arange(-15, 15, 2)
Y = np.arange(-15, 15, 2)

X, Y = np.meshgrid(X, Y)

Z = 9*X + 204
Z2 = 9*X + 10
ax.plot_wireframe(X, Y, Z, linestyle='--', linewidth=1)
ax.plot_wireframe(X, Y, Z2,colors='green')


plt.show()

# %% [markdown]
# 2. Нарисуйте трехмерный график двух любых поверхностей второго порядка.

# %%
fig = plt.figure(figsize = (18, 18))
ax = Axes3D(fig)

a = 20
b = 90

X, Y = np.meshgrid((np.arange(-15, 15, 2)), (np.arange(-15, 15, 2)))

Z = b ** 2 + (b ** 2 * (X ** 2 / a ** 2))
Z1 = -(b ** 2 + (b ** 2 * (X ** 2 / a ** 2)))
Z2 = 2*a*X ** np.cos(40) + np.sqrt(2*a*X ** np.cos(40))
ax.plot_surface(X, Y, Z,  linewidth=1, color='g')
ax.plot_surface(X, Y, Z1,  linewidth=1, color='g')

u = np.linspace(0,2*np.pi, 32)
v = np.linspace(0, np.pi, 16)

x = 10 * np.outer(np.cos(u), np.sin(v))
y = 50 * np.outer(np.sin(u), np.sin(v))
z = -100 * np.outer(np.ones(np.size(u)), np.cos(v))

ax.plot_surface(x, y, z, rstride=4, cstride=4, color='r')


plt.show()
# Out:
# <ipython-input-13-e1359ea581b6>:11: RuntimeWarning: invalid value encountered in power
#   Z2 = 2*a*X ** np.cos(40) + np.sqrt(2*a*X ** np.cos(40))
